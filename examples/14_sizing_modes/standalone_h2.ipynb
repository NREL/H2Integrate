# %% [markdown]
# # Demonstrating different compute modes with standalone H2 electrolyzer
#
# This notebook shows how to use different compute modes (`normal`, `feedstock_size`, and `product_size`) using a simple system with only one complex converter, and two simple converters connected to it.
# These simple converters are the new `feedstock_profile` and `product_profile` class, and simply function as dictated energy/mass flow profiles that can be set in a .csv rather than calculated by a model.
#
# ## Compute modes
#
# For the converters involved in this example, three different `compute_mode` parameters have been defined, which determine how the `PerformanceModel.compute()` function will execute and which variables to create in the `PerformanceModel.setup()` function.
#
# - `normal`: In this mode, converters function as they always have previously:
#     - The size of the asset is fixed within the `compute()` function, and is read from the config.
#     - The feedstock profiles are fixed and set as the `<feedstock>_in` inputs, typically from a connection to another upstream converter.
#     - The product profiles are calculated and set as the `<product>_out` outputs, and may be passed to another downstream converter.
# - `feedstock_size`: In this mode, the size of the asset is adjusted to be able to utilize all of the available feedstock:
#     - The size of the asset is *calculated* within the `compute()` function, by how big it needs to be to utilize all of the `<feedstock>_in`.
#     - The feedstock profiles are fixed and set as the `<feedstock>_in` inputs, typically from a connection to another upstream converter - same as `normal` mode.
#     - The product profiles are calculated and set as the `<product>_out` outputs, and may be passed to another downstream converter - same as `normal` mode.
# - `product_size`: In this mode, the size of the asset is adjusted to be able to meet the demand profile for its product:
#     - The size of the asset is calculated within the `compute()` function, by how big it needs to be to provide all of the `<product>_demand` - a new input that is defined in `setup()` just for this mode.
#     - The feedstock profiles are *calculated* and set as the `<feedstock>_consume` *outputs*, and may be passed to another upstream converter.
#     - The product profiles are *fixed* and set as the `<product>_demand` *inputs*, typically from a connection to another downstream converter.
#
# ## Example plant setup
#
# Here, there are three technologies in the the `tech_config.yaml`: And `electrolyzer`, a `feedstock_profile` (configured for electricity), and a `product_profile` (configured for hydrogen).
# The feedstock/product profiles are very simple converters that are set up to either read a .csv file that defines the profile OR function as a flexible input/output source of the commodity.
# In both cases, a simple buying or selling price is set for the commodity to feed into financial calculations.
#
# ### Example technology_interconnections within plant_config.yaml
# ```yaml
# technology_interconnections: [
#   ["feedstock_profile", "electrolyzer", "electricity", "cable"],
#   ["electrolyzer", "product_profile", "hydrogen", "pipe"]
# ]
# ```
# In `normal` mode or `feedstock_size` mode, the interconnection will behave as they previously have - connecting from `<source_tech>.outputs["<commodity>_out"]` to `<dest_tech>.inputs["<commodity>_in"]`
# However, if the destination technology is in `product_size` mode, the interconnection will instead be made from `<dest_tech>.outputs["<commodity>_demand"]` to `<source_tech>.inputs["<commodity>_consume"]`
#
# ### Example tech_config.yaml (some parameters skipped for brevity)
# ```yaml
# technologies:
#   electrolyzer:
#     performance_model:
#       model: "eco_pem_electrolyzer_performance"
#     cost_model:
#       model: "singlitico_electrolyzer_cost"
#     model_inputs:
#       performance_parameters:
#         compute_mode: "product_size"
#         size_by: "hydrogen"
#   feedstock_profile:
#     performance_model:
#       model: "feedstock_performance"
#     cost_model:
#       model: "feedstock_cost"
#     model_inputs:
#       shared_parameters:
#         commodity: "electricity"
#       performance_parameters:
#         compute_mode: "product_size"
#         profile: "elec_profile.csv"
#         unit: "kW"
#       cost_parameters:
#         buy_price: 0.07
#   product_profile:
#     performance_model:
#       model: "product_performance"
#     cost_model:
#       model: "product_cost"
#     model_inputs:
#       shared_parameters:
#         commodity: "hydrogen"
#       performance_parameters:
#         compute_mode: "product_size"
#         profile: "h2_profile.csv"
#         unit: "kg/h"
#       cost_parameters:
#         sell_price: 1.50
#         is_coproduct: False
# ```

# %% [markdown]
# ## Running an example
#
# ### `normal` mode
#
# The example `.yaml` files have been set up in `normal` mode.
# In this case, an electricity profile will be read in by the `feedstock_profile`, and the electrolyzer will utilize whatever `electricity_in` it can at the size that has been set in the config.
# The `product_profile` will simply act as an "end cap" for the `hydrogen_out` profile to be passed to.
#
# In this case the electrolyzer has been sized to 640 MW (same as previous example), but the electricity profile going in only has a max of 600 MW.
# Thus, the LCOH ($5.33/kg) is not quite optimal - the electrolyzer size should be reduced.

# %%
from h2integrate.core.h2integrate_model import H2IntegrateModel


# Create a H2Integrate model
model = H2IntegrateModel("14_standalone_h2_pem_normal.yaml")

# Run the model
model.run()

model.post_process()
# Out:
# 25 Input(s) in 'model'
#
# varname                                    val                  units     prom_name
# -----------------------------------------  -------------------  --------  ------------------------------------------------------
# plant
#   feedstock_profile
#     feedstock_performance
#       electricity_profile                  |39730239.80618451|  kW        feedstock_profile.electricity_profile
#     feedstock_cost
#       electricity_out                      |39730239.80618451|  kW        feedstock_profile.electricity_out
#   feedstock_profile_to_electrolyzer_cable
#     electricity_in                         |39730239.80618451|  kW        feedstock_profile_to_electrolyzer_cable.electricity_in
#   electrolyzer
#     eco_pem_electrolyzer_performance
#       electrolyzer_size_mw                 [640.]               MW        electrolyzer.electrolyzer_size_mw
#       electricity_in                       |39730239.80618451|  kW        electrolyzer.electricity_in
#     singlitico_electrolyzer_cost
#       total_hydrogen_produced              [67270531.37723792]  kg/year   electrolyzer.total_hydrogen_produced
#       electricity_consume                  |93.59487165|        kW        electrolyzer.electricity_consume
#       electrolyzer_size_mw_cost            [640.]               MW        electrolyzer.electrolyzer_size_mw_cost
#   electrolyzer_to_product_profile_pipe
#     hydrogen_in                            |219.72599339|       kg/s      electrolyzer_to_product_profile_pipe.hydrogen_in
#   product_profile
#     product_performance
#       hydrogen_in                          |791013.57620763|    kg/h      product_profile.hydrogen_in
#     product_cost
#       hydrogen_consume                     |791013.57620763|    kg/h      product_profile.hydrogen_consume
#   financials_group_1
#     adjusted_capex_opex_comp
#       capex_electrolyzer                   [6.00412524e+08]     USD       financials_group_1.capex_electrolyzer
#       opex_electrolyzer                    [14703155.39207595]  USD/year  financials_group_1.opex_electrolyzer
#       capex_feedstock_profile              [0.]                 USD       financials_group_1.capex_feedstock_profile
#       opex_feedstock_profile               [2.45369527e+08]     USD/year  financials_group_1.opex_feedstock_profile
#       capex_product_profile                [0.]                 USD       financials_group_1.capex_product_profile
#       opex_product_profile                 [0.]                 USD/year  financials_group_1.opex_product_profile
#     profast_comp_0
#       capex_adjusted_electrolyzer          [6.96294452e+08]     USD       financials_group_1.capex_adjusted_electrolyzer
#       opex_adjusted_electrolyzer           [17051152.53515185]  USD/year  financials_group_1.opex_adjusted_electrolyzer
#       capex_adjusted_feedstock_profile     [0.]                 USD       financials_group_1.capex_adjusted_feedstock_profile
#       opex_adjusted_feedstock_profile      [2.64236144e+08]     USD/year  financials_group_1.opex_adjusted_feedstock_profile
#       capex_adjusted_product_profile       [0.]                 USD       financials_group_1.capex_adjusted_product_profile
#       opex_adjusted_product_profile        [0.]                 USD/year  financials_group_1.opex_adjusted_product_profile
#       total_hydrogen_produced              [67270531.37723792]  kg/year   financials_group_1.total_hydrogen_produced
#       time_until_replacement               [82813.52953414]     h         financials_group_1.time_until_replacement
#
#
# 36 Explicit Output(s) in 'model'
#
# varname                                    val                  units      prom_name
# -----------------------------------------  -------------------  ---------  -------------------------------------------------------------
# site
#   site_component
#     latitude                               [47.5233]            None       latitude
#     longitude                              [-92.5366]           None       longitude
#     elevation_m                            [439.]               None       elevation_m
#     time_zone                              [-5.]                None       time_zone
#     boundary_0_x                           |1414.21356237|      None       boundary_0_x
#     boundary_0_y                           |1004.98756211|      None       boundary_0_y
#     boundary_1_x                           |3774.91721764|      None       boundary_1_x
#     boundary_1_y                           |3774.91721764|      None       boundary_1_y
# plant
#   feedstock_profile
#     feedstock_performance
#       electricity_out                      |39730239.80618451|  kW         feedstock_profile.electricity_out
#     feedstock_cost
#       CapEx                                [0.]                 USD        feedstock_profile.CapEx
#       OpEx                                 [2.45369527e+08]     USD/year   feedstock_profile.OpEx
#   feedstock_profile_to_electrolyzer_cable
#     electricity_out                        |39730239.80618451|  kW         feedstock_profile_to_electrolyzer_cable.electricity_out
#   electrolyzer
#     eco_pem_electrolyzer_performance
#       time_until_replacement               [82813.52953414]     h          electrolyzer.time_until_replacement
#       total_hydrogen_produced              [67270531.37723792]  kg/year    electrolyzer.total_hydrogen_produced
#       efficiency                           [0.78937]            None       electrolyzer.efficiency
#       rated_h2_production_kg_pr_hr         [12549.67157762]     kg/h       electrolyzer.rated_h2_production_kg_pr_hr
#       hydrogen_out                         |791013.57620763|    kg/h       electrolyzer.hydrogen_out
#       electricity_consume                  |93.59487165|        kW         electrolyzer.electricity_consume
#       water_consume                        |7910135.7620763|    kg/h       electrolyzer.water_consume
#       electrolyzer_size_mw_cost            [640.]               MW         electrolyzer.electrolyzer_size_mw_cost
#     singlitico_electrolyzer_cost
#       CapEx                                [6.00412524e+08]     USD        electrolyzer.CapEx
#       OpEx                                 [14703155.39207595]  USD/year   electrolyzer.OpEx
#   electrolyzer_to_product_profile_pipe
#     hydrogen_out                           |219.72599339|       kg/s       electrolyzer_to_product_profile_pipe.hydrogen_out
#   product_profile
#     product_performance
#       hydrogen_consume                     |791013.57620763|    kg/h       product_profile.hydrogen_consume
#     product_cost
#       CapEx                                [0.]                 USD        product_profile.CapEx
#       OpEx                                 [0.]                 USD/year   product_profile.OpEx
#   financials_group_1
#     electricity_sum
#       total_electricity_produced           [0.]                 kW*h/year  financials_group_1.electricity_sum.total_electricity_produced
#     adjusted_capex_opex_comp
#       capex_adjusted_electrolyzer          [6.96294452e+08]     USD        financials_group_1.capex_adjusted_electrolyzer
#       opex_adjusted_electrolyzer           [17051152.53515185]  USD/year   financials_group_1.opex_adjusted_electrolyzer
#       capex_adjusted_feedstock_profile     [0.]                 USD        financials_group_1.capex_adjusted_feedstock_profile
#       opex_adjusted_feedstock_profile      [2.64236144e+08]     USD/year   financials_group_1.opex_adjusted_feedstock_profile
#       capex_adjusted_product_profile       [0.]                 USD        financials_group_1.capex_adjusted_product_profile
#       opex_adjusted_product_profile        [0.]                 USD/year   financials_group_1.opex_adjusted_product_profile
#       total_capex_adjusted                 [6.96294452e+08]     USD        financials_group_1.total_capex_adjusted
#       total_opex_adjusted                  [2.81287296e+08]     USD/year   financials_group_1.total_opex_adjusted
#     profast_comp_0
#       LCOH                                 [5.33181353]         USD/kg     financials_group_1.LCOH
#
#
# 0 Implicit Output(s) in 'model'

# %% [markdown]
# ### `feedstock_size` mode
#
# In this case, the electrolyzer will be sized to match the electricity supply profile going in thru `elec_profile.csv`.
# This reduces the electrolyzer size to 600 MW, optimizing the LCOH to $5.27/kg.
# Note that this does not require used of the optimizer, saving valuable computation time in a multivariable optimization.

# %%
# Create a H2Integrate model
feed_model = H2IntegrateModel("14_standalone_h2_pem_feedstock_size.yaml")

# Run the model
feed_model.run()

feed_model.post_process()
# Out:
# 25 Input(s) in 'model'
#
# varname                                    val                   units     prom_name
# -----------------------------------------  --------------------  --------  ------------------------------------------------------
# plant
#   feedstock_profile
#     feedstock_performance
#       electricity_profile                  |39730239.80618451|   kW        feedstock_profile.electricity_profile
#     feedstock_cost
#       electricity_out                      |39730239.80618451|   kW        feedstock_profile.electricity_out
#   feedstock_profile_to_electrolyzer_cable
#     electricity_in                         |39730239.80618451|   kW        feedstock_profile_to_electrolyzer_cable.electricity_in
#   electrolyzer
#     eco_pem_electrolyzer_performance
#       electrolyzer_size_mw                 [640.]                MW        electrolyzer.electrolyzer_size_mw
#       electricity_in                       |39730239.80618451|   kW        electrolyzer.electricity_in
#     singlitico_electrolyzer_cost
#       total_hydrogen_produced              [67016048.92718399]   kg/year   electrolyzer.total_hydrogen_produced
#       electricity_consume                  |93.59487165|         kW        electrolyzer.electricity_consume
#       electrolyzer_size_mw_cost            [599.9999992]         MW        electrolyzer.electrolyzer_size_mw_cost
#   electrolyzer_to_product_profile_pipe
#     hydrogen_in                            |218.78522272|        kg/s      electrolyzer_to_product_profile_pipe.hydrogen_in
#   product_profile
#     product_performance
#       hydrogen_in                          |787626.80178879|     kg/h      product_profile.hydrogen_in
#     product_cost
#       hydrogen_consume                     |787626.80178879|     kg/h      product_profile.hydrogen_consume
#   financials_group_1
#     adjusted_capex_opex_comp
#       capex_electrolyzer                   [5.6288674e+08]       USD       financials_group_1.capex_electrolyzer
#       opex_electrolyzer                    [13784208.16169226]   USD/year  financials_group_1.opex_electrolyzer
#       capex_feedstock_profile              [0.]                  USD       financials_group_1.capex_feedstock_profile
#       opex_feedstock_profile               [2.45369527e+08]      USD/year  financials_group_1.opex_feedstock_profile
#       capex_product_profile                [0.]                  USD       financials_group_1.capex_product_profile
#       opex_product_profile                 [0.]                  USD/year  financials_group_1.opex_product_profile
#     profast_comp_0
#       capex_adjusted_electrolyzer          [6.52776048e+08]      USD       financials_group_1.capex_adjusted_electrolyzer
#       opex_adjusted_electrolyzer           [15985455.48039092]   USD/year  financials_group_1.opex_adjusted_electrolyzer
#       capex_adjusted_feedstock_profile     [0.]                  USD       financials_group_1.capex_adjusted_feedstock_profile
#       opex_adjusted_feedstock_profile      [2.64236144e+08]      USD/year  financials_group_1.opex_adjusted_feedstock_profile
#       capex_adjusted_product_profile       [0.]                  USD       financials_group_1.capex_adjusted_product_profile
#       opex_adjusted_product_profile        [0.]                  USD/year  financials_group_1.opex_adjusted_product_profile
#       total_hydrogen_produced              [67016048.92718399]   kg/year   financials_group_1.total_hydrogen_produced
#       time_until_replacement               [82476.23298458]      h         financials_group_1.time_until_replacement
#
#
# 36 Explicit Output(s) in 'model'
#
# varname                                    val                   units      prom_name
# -----------------------------------------  --------------------  ---------  -------------------------------------------------------------
# site
#   site_component
#     latitude                               [47.5233]             None       latitude
#     longitude                              [-92.5366]            None       longitude
#     elevation_m                            [439.]                None       elevation_m
#     time_zone                              [-5.]                 None       time_zone
#     boundary_0_x                           |1414.21356237|       None       boundary_0_x
#     boundary_0_y                           |1004.98756211|       None       boundary_0_y
#     boundary_1_x                           |3774.91721764|       None       boundary_1_x
#     boundary_1_y                           |3774.91721764|       None       boundary_1_y
# plant
#   feedstock_profile
#     feedstock_performance
#       electricity_out                      |39730239.80618451|   kW         feedstock_profile.electricity_out
#     feedstock_cost
#       CapEx                                [0.]                  USD        feedstock_profile.CapEx
#       OpEx                                 [2.45369527e+08]      USD/year   feedstock_profile.OpEx
#   feedstock_profile_to_electrolyzer_cable
#     electricity_out                        |39730239.80618451|   kW         feedstock_profile_to_electrolyzer_cable.electricity_out
#   electrolyzer
#     eco_pem_electrolyzer_performance
#       time_until_replacement               [82476.23298458]      h          electrolyzer.time_until_replacement
#       total_hydrogen_produced              [67016048.92718399]   kg/year    electrolyzer.total_hydrogen_produced
#       efficiency                           [0.7860767]           None       electrolyzer.efficiency
#       rated_h2_production_kg_pr_hr         [11765.31710401]      kg/h       electrolyzer.rated_h2_production_kg_pr_hr
#       hydrogen_out                         |787626.80178879|     kg/h       electrolyzer.hydrogen_out
#       electricity_consume                  |93.59487165|         kW         electrolyzer.electricity_consume
#       water_consume                        |7876268.0178879|     kg/h       electrolyzer.water_consume
#       electrolyzer_size_mw_cost            [599.9999992]         MW         electrolyzer.electrolyzer_size_mw_cost
#     singlitico_electrolyzer_cost
#       CapEx                                [5.6288674e+08]       USD        electrolyzer.CapEx
#       OpEx                                 [13784208.16169226]   USD/year   electrolyzer.OpEx
#   electrolyzer_to_product_profile_pipe
#     hydrogen_out                           |218.78522272|        kg/s       electrolyzer_to_product_profile_pipe.hydrogen_out
#   product_profile
#     product_performance
#       hydrogen_consume                     |787626.80178879|     kg/h       product_profile.hydrogen_consume
#     product_cost
#       CapEx                                [0.]                  USD        product_profile.CapEx
#       OpEx                                 [0.]                  USD/year   product_profile.OpEx
#   financials_group_1
#     electricity_sum
#       total_electricity_produced           [0.]                  kW*h/year  financials_group_1.electricity_sum.total_electricity_produced
#     adjusted_capex_opex_comp
#       capex_adjusted_electrolyzer          [6.52776048e+08]      USD        financials_group_1.capex_adjusted_electrolyzer
#       opex_adjusted_electrolyzer           [15985455.48039092]   USD/year   financials_group_1.opex_adjusted_electrolyzer
#       capex_adjusted_feedstock_profile     [0.]                  USD        financials_group_1.capex_adjusted_feedstock_profile
#       opex_adjusted_feedstock_profile      [2.64236144e+08]      USD/year   financials_group_1.opex_adjusted_feedstock_profile
#       capex_adjusted_product_profile       [0.]                  USD        financials_group_1.capex_adjusted_product_profile
#       opex_adjusted_product_profile        [0.]                  USD/year   financials_group_1.opex_adjusted_product_profile
#       total_capex_adjusted                 [6.52776048e+08]      USD        financials_group_1.total_capex_adjusted
#       total_opex_adjusted                  [2.80221599e+08]      USD/year   financials_group_1.total_opex_adjusted
#     profast_comp_0
#       LCOH                                 [5.26553916]          USD/kg     financials_group_1.LCOH
#
#
# 0 Implicit Output(s) in 'model'

# %% [markdown]
# ### `product_size` mode
#
# In this case, the electrolyzer will be sized to match the hydrogen demand profile going in thru `h2_profile.csv`.
# The hydrogen demand profile is the same hydrogen output profile that was previously calculated in `feedstock_size` mode, to test if there is any difference going forward and backward.
# It reduces the electrolyzer size to 600 MW, optimizing the LCOH to $5.27/kg, but with a slight difference in the trailing digits.
# This is because in `product_size` the electrolyzer performance is calculated iteratively.
# It starts with a best guess of the electricity profile required to meet the hydrogen demand, then calculates the residual between the hydrogen demand profile and the hydrogen produced.
# The residuals are used to correct the electricity profile iteratively until a minimum max residual is achieved (below a ratio of 1e-6 between the maximum hydrogen produced and the maximum residual).
# This results in a small but insignificant difference in the LCOH calculated in `feedstock_size` and `product_size` methods.

# %%
# Create a H2Integrate model
prod_model = H2IntegrateModel("14_standalone_h2_pem_product_size.yaml")

# Run the model
prod_model.run()

prod_model.post_process()
# Out:
# 25 Input(s) in 'model'
#
# varname                                    val                   units     prom_name
# -----------------------------------------  --------------------  --------  ------------------------------------------------------
# plant
#   product_profile
#     product_performance
#       hydrogen_profile                     |787626.80178713|     kg/h      product_profile.hydrogen_profile
#     product_cost
#       hydrogen_consume                     |787626.80178713|     kg/h      product_profile.hydrogen_consume
#   electrolyzer_to_product_profile_pipe
#     hydrogen_in                            |218.78522272|        kg/s      electrolyzer_to_product_profile_pipe.hydrogen_in
#   electrolyzer
#     eco_pem_electrolyzer_performance
#       electrolyzer_size_mw                 [640.]                MW        electrolyzer.electrolyzer_size_mw
#       hydrogen_demand                      |787626.80178713|     kg/h      electrolyzer.hydrogen_demand
#     singlitico_electrolyzer_cost
#       total_hydrogen_produced              [67016048.83064488]   kg/year   electrolyzer.total_hydrogen_produced
#       electricity_consume                  |39730239.28623783|   kW        electrolyzer.electricity_consume
#       electrolyzer_size_mw_cost            [599.91449328]        MW        electrolyzer.electrolyzer_size_mw_cost
#   feedstock_profile_to_electrolyzer_cable
#     electricity_in                         |39730239.28623783|   kW        feedstock_profile_to_electrolyzer_cable.electricity_in
#   feedstock_profile
#     feedstock_performance
#       electricity_demand                   |39730239.28623783|   kW        feedstock_profile.electricity_demand
#     feedstock_cost
#       electricity_out                      |39730239.28623783|   kW        feedstock_profile.electricity_out
#   financials_group_1
#     adjusted_capex_opex_comp
#       capex_electrolyzer                   [5.62806523e+08]      USD       financials_group_1.capex_electrolyzer
#       opex_electrolyzer                    [13782243.77602242]   USD/year  financials_group_1.opex_electrolyzer
#       capex_feedstock_profile              [0.]                  USD       financials_group_1.capex_feedstock_profile
#       opex_feedstock_profile               [2.45369527e+08]      USD/year  financials_group_1.opex_feedstock_profile
#       capex_product_profile                [0.]                  USD       financials_group_1.capex_product_profile
#       opex_product_profile                 [0.]                  USD/year  financials_group_1.opex_product_profile
#     profast_comp_0
#       capex_adjusted_electrolyzer          [6.52683021e+08]      USD       financials_group_1.capex_adjusted_electrolyzer
#       opex_adjusted_electrolyzer           [15983177.39525877]   USD/year  financials_group_1.opex_adjusted_electrolyzer
#       capex_adjusted_feedstock_profile     [0.]                  USD       financials_group_1.capex_adjusted_feedstock_profile
#       opex_adjusted_feedstock_profile      [2.64236143e+08]      USD/year  financials_group_1.opex_adjusted_feedstock_profile
#       capex_adjusted_product_profile       [0.]                  USD       financials_group_1.capex_adjusted_product_profile
#       opex_adjusted_product_profile        [0.]                  USD/year  financials_group_1.opex_adjusted_product_profile
#       total_hydrogen_produced              [67016048.83064488]   kg/year   financials_group_1.total_hydrogen_produced
#       time_until_replacement               [82476.23296947]      h         financials_group_1.time_until_replacement
#
#
# 35 Explicit Output(s) in 'model'
#
# varname                                    val                   units      prom_name
# -----------------------------------------  --------------------  ---------  -------------------------------------------------------------
# site
#   site_component
#     latitude                               [47.5233]             None       latitude
#     longitude                              [-92.5366]            None       longitude
#     elevation_m                            [439.]                None       elevation_m
#     time_zone                              [-5.]                 None       time_zone
#     boundary_0_x                           |1414.21356237|       None       boundary_0_x
#     boundary_0_y                           |1004.98756211|       None       boundary_0_y
#     boundary_1_x                           |3774.91721764|       None       boundary_1_x
#     boundary_1_y                           |3774.91721764|       None       boundary_1_y
# plant
#   product_profile
#     product_performance
#       hydrogen_consume                     |787626.80178713|     kg/h       product_profile.hydrogen_consume
#     product_cost
#       CapEx                                [0.]                  USD        product_profile.CapEx
#       OpEx                                 [0.]                  USD/year   product_profile.OpEx
#   electrolyzer_to_product_profile_pipe
#     hydrogen_out                           |218.78522272|        kg/s       electrolyzer_to_product_profile_pipe.hydrogen_out
#   electrolyzer
#     eco_pem_electrolyzer_performance
#       time_until_replacement               [82476.23296947]      h          electrolyzer.time_until_replacement
#       total_hydrogen_produced              [67016048.83064488]   kg/year    electrolyzer.total_hydrogen_produced
#       efficiency                           [0.7860767]           None       electrolyzer.efficiency
#       rated_h2_production_kg_pr_hr         [11765.31710401]      kg/h       electrolyzer.rated_h2_production_kg_pr_hr
#       electricity_consume                  |39730239.28623783|   kW         electrolyzer.electricity_consume
#       water_consume                        |7876267.93694606|    kg/h       electrolyzer.water_consume
#       electrolyzer_size_mw_cost            [599.91449328]        MW         electrolyzer.electrolyzer_size_mw_cost
#     singlitico_electrolyzer_cost
#       CapEx                                [5.62806523e+08]      USD        electrolyzer.CapEx
#       OpEx                                 [13782243.77602242]   USD/year   electrolyzer.OpEx
#   feedstock_profile_to_electrolyzer_cable
#     electricity_out                        |39730239.28623783|   kW         feedstock_profile_to_electrolyzer_cable.electricity_out
#   feedstock_profile
#     feedstock_performance
#       electricity_out                      |39730239.28623783|   kW         feedstock_profile.electricity_out
#     feedstock_cost
#       CapEx                                [0.]                  USD        feedstock_profile.CapEx
#       OpEx                                 [2.45369527e+08]      USD/year   feedstock_profile.OpEx
#   financials_group_1
#     electricity_sum
#       total_electricity_produced           [0.]                  kW*h/year  financials_group_1.electricity_sum.total_electricity_produced
#     adjusted_capex_opex_comp
#       capex_adjusted_electrolyzer          [6.52683021e+08]      USD        financials_group_1.capex_adjusted_electrolyzer
#       opex_adjusted_electrolyzer           [15983177.39525877]   USD/year   financials_group_1.opex_adjusted_electrolyzer
#       capex_adjusted_feedstock_profile     [0.]                  USD        financials_group_1.capex_adjusted_feedstock_profile
#       opex_adjusted_feedstock_profile      [2.64236143e+08]      USD/year   financials_group_1.opex_adjusted_feedstock_profile
#       capex_adjusted_product_profile       [0.]                  USD        financials_group_1.capex_adjusted_product_profile
#       opex_adjusted_product_profile        [0.]                  USD/year   financials_group_1.opex_adjusted_product_profile
#       total_capex_adjusted                 [6.52683021e+08]      USD        financials_group_1.total_capex_adjusted
#       total_opex_adjusted                  [2.8021932e+08]       USD/year   financials_group_1.total_opex_adjusted
#     profast_comp_0
#       LCOH                                 [5.26535421]          USD/kg     financials_group_1.LCOH
#
#
# 0 Implicit Output(s) in 'model'
